# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Lake.jpg')

# %%
cv2.imshow('image',img)
k = cv2.waitKey(0)
if k == 27:         
    cv2.destroyAllWindows()
elif k == ord('s'): 
    cv2.imwrite('messigray.png',img)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30728/1108041278.py in <module>
# ----> 1 cv2.imshow('image',img)
#       2 k = cv2.waitKey(0)
#       3 if k == 27:
#       4     cv2.destroyAllWindows()
#       5 elif k == ord('s'):
#
# error: OpenCV(4.5.4-dev) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#print using matplotlib 
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30772/879115067.py in <module>
#       1 #print using matplotlib
# ----> 2 plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#       3 plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
#access a pixel BGR
px = img[100,100]
print(px)
# Out:
# [180 181 172]

# %%
blue = img[100,100,0]
green = img[100,100,1]
red = img[100,100,2]
print('Blue pixel value:',blue,'Green pixel value:',green,'Red pixel value:',red)
# Out:
# Blue pixel value: 180 Green pixel value: 181 Red pixel value: 172

# %%
# modifying pixel value
img[100,100] = [255,255,255]
print (img[100,100])
# Out:
# [255 255 255]

# %%
# accessing RED channel pixel value
img.item(10,10,2)
# Out:
# 171

# %%
# modifying RED channel pixel value
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %%
#image shape
print(img.shape)
#image size (totoal number of pixels)
print(img.size)
# image datatype
print (img.dtype)
# Out:
# (2340, 4160, 3)
# 29203200
# uint8

# %%
# copy a group of pixels
glasses = img[200:280, 370:560,:]
img2 = img
img2[173:253, 90:280] = glasses
cv2.imshow('image',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9020/4042421794.py in <module>
#       1 # copy a group of pixels
# ----> 2 glasses = img[200:280, 370:560,:]
#       3 img2 = img
#       4 img2[173:253, 90:280] = glasses
#       5 cv2.imshow('image',img2)
#
# NameError: name 'img' is not defined

# %%
b,g,r = cv2.split(img)
img = cv2.merge((b,g,r))

# %%
plt.imshow(b)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

BLUE = [255,0,0]

img1 = cv2.imread('Lake.jpg')

replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

plt.show()

# %%
#converting RGB image to Binary 

gray_image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) 
ret,thresh = cv2.threshold(gray_image,127,255,0) 
#calculate the contours from binary image
im,contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE) 
with_contours = cv2.drawContours(img,contours,-1,(0,255,0),3) 
plt.imshow(with_contours)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7244/2555672187.py in <module>
#       5 ret,thresh = cv2.threshold(gray_image,127,255,0)
#       6 #calculate the contours from binary image
# ----> 7 im,contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
#       8 with_contours = cv2.drawContours(img,contours,-1,(0,255,0),3)
#       9 plt.imshow(with_contours)
#
# ValueError: not enough values to unpack (expected 3, got 2)
